# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = "/home/zhaosheng/Documents/ScanNetAI/egs/ct2dose/exp/unetr/eval_niis/1/0000/image.npy"
label = "/home/zhaosheng/Documents/ScanNetAI/egs/ct2dose/exp/unetr/eval_niis/1/0000/label.npy"
pred = "/home/zhaosheng/Documents/ScanNetAI/egs/ct2dose/exp/unetr/eval_niis/1/0000/pred.npy"

# plot image
img = np.load(img)
# print(img.shape)
img = img[0, :, 50, :]
plt.figure()
plt.imshow(img, cmap='gray')

pred = np.load(pred)
# print(pred.shape)
pred = pred[0, :, 50, :]
plt.figure()
plt.imshow(pred, cmap='gray')

label = np.load(label)
label = label[0, :, 50, :]
plt.figure()
plt.imshow(label, cmap='gray')
