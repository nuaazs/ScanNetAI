# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
root = "/home/zhaosheng/Documents/ScanNetAI/egs/ct2dose/common/niis_selected/RT201561"
img = root + "/ct.nii.gz"
label = root + "/dose.nii.gz"
pred = root + "/struct.nii.gz"

def load_nii_to_array(filename):
    import nibabel as nib
    img = nib.load(filename)
    data = img.get_fdata()
    print(data.shape)
    return data

# plot image
img = load_nii_to_array(img)
# print(img.shape)
img = img[:, 50, :]
plt.figure()
plt.imshow(img, cmap='gray')

pred = load_nii_to_array(pred)
# print(pred.shape)
pred = pred[:, 50, :]
plt.figure()
plt.imshow(pred, cmap='gray')

label = load_nii_to_array(label)
label = label[:, 50, :]
plt.figure()
plt.imshow(label, cmap='gray')
# Out:
# (146, 92, 141)
# (146, 92, 141)
# (146, 92, 141)

# %%
root = "./exp/unetr/eval_niis/50/0002_0001/"
img = root + "image.npy"
label = root + "label.npy"
pred = root + "pred.npy"

def load_nii_to_array(filename):
    return np.load(filename)[0]

# plot image
img = load_nii_to_array(img)
# print(img.shape)
img = img[:, 50, :]
plt.figure()
plt.imshow(img, cmap='gray')
plt.colorbar()
plt.show()

pred = load_nii_to_array(pred)
# print(pred.shape)
pred = pred[:, 50, :]


plt.figure()
plt.imshow(pred, cmap='gray')
plt.colorbar()
plt.show()

label = load_nii_to_array(label)
label = label[:, 50, :]
plt.figure()
plt.imshow(label, cmap='gray')
plt.colorbar()
plt.show()

# %%
root = "./exp/unetr/eval_niis/100/0002_0001/"
img = root + "image.npy"
label = root + "label.npy"
pred = root + "pred.npy"

def load_nii_to_array(filename):
    return np.load(filename)[0]

# plot image
img = load_nii_to_array(img)
# print(img.shape)
img = img[:, 50, :]
plt.figure()
plt.imshow(img, cmap='gray')
plt.colorbar()
plt.show()

pred = load_nii_to_array(pred)
# print(pred.shape)
pred = pred[:, 50, :]


plt.figure()
plt.imshow(pred, cmap='gray')
plt.colorbar()
plt.show()

label = load_nii_to_array(label)
label = label[:, 50, :]
plt.figure()
plt.imshow(label, cmap='gray')
plt.colorbar()
plt.show()
